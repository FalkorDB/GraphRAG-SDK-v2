# %%
from falkordb_gemini_kg import (
    Orchestrator,
    Ontology,
    OrchestratorRunner,
    Entity,
    Relation,
    Attribute,
    AttributeType,
    KnowledgeGraph,
    KnowledgeGraphModelConfig,
)
from falkordb_gemini_kg.agents.kg_agent import KGAgent
from falkordb_gemini_kg.models.gemini import GeminiGenerativeModel

from json import loads
from falkordb import FalkorDB
import os
import vertexai
import logging

logging.basicConfig(level=logging.DEBUG)

vertexai.init(project=os.getenv("PROJECT_ID"), location=os.getenv("REGION"))

restaurants_ontology = Ontology()
restaurants_ontology.add_entity(
    Entity(
        label="Country",
        attributes=[
            Attribute(
                name="name",
                attr_type=AttributeType.STRING,
                required=True,
                unique=True,
            ),
        ],
    )
)
restaurants_ontology.add_entity(
    Entity(
        label="City",
        attributes=[
            Attribute(
                name="name",
                attr_type=AttributeType.STRING,
                required=True,
                unique=True,
            ),
            Attribute(
                name="weather",
                attr_type=AttributeType.STRING,
                required=False,
                unique=False,
            ),
            Attribute(
                name="population",
                attr_type=AttributeType.NUMBER,
                required=False,
                unique=False,
            ),
        ],
    )
)
restaurants_ontology.add_entity(
    Entity(
        label="Restaurant",
        attributes=[
            Attribute(
                name="name",
                attr_type=AttributeType.STRING,
                required=True,
                unique=True,
            ),
            Attribute(
                name="description",
                attr_type=AttributeType.STRING,
                required=False,
                unique=False,
            ),
            Attribute(
                name="rating",
                attr_type=AttributeType.NUMBER,
                required=False,
                unique=False,
            ),
            Attribute(
                name="food_type",
                attr_type=AttributeType.STRING,
                required=False,
                unique=False,
            ),
        ],
    )
)
restaurants_ontology.add_relation(
    Relation(
        label="IN_COUNTRY",
        source="City",
        target="Country",
    )
)
restaurants_ontology.add_relation(
    Relation(
        label="IN_CITY",
        source="Restaurant",
        target="City",
    )
)


attractions_ontology = Ontology()
attractions_ontology.add_entity(
    Entity(
        label="Country",
        attributes=[
            Attribute(
                name="name",
                attr_type=AttributeType.STRING,
                required=True,
                unique=True,
            ),
        ],
    )
)
attractions_ontology.add_entity(
    Entity(
        label="City",
        attributes=[
            Attribute(
                name="name",
                attr_type=AttributeType.STRING,
                required=True,
                unique=True,
            ),
            Attribute(
                name="weather",
                attr_type=AttributeType.STRING,
                required=False,
                unique=False,
            ),
            Attribute(
                name="population",
                attr_type=AttributeType.NUMBER,
                required=False,
                unique=False,
            ),
        ],
    )
)
attractions_ontology.add_entity(
    Entity(
        label="Attraction",
        attributes=[
            Attribute(
                name="name",
                attr_type=AttributeType.STRING,
                required=True,
                unique=True,
            ),
            Attribute(
                name="description",
                attr_type=AttributeType.STRING,
                required=False,
                unique=False,
            ),
            Attribute(
                name="type",
                attr_type=AttributeType.STRING,
                required=False,
                unique=False,
            ),
        ],
    )
)
attractions_ontology.add_relation(
    Relation(
        label="IN_COUNTRY",
        source="City",
        target="Country",
    )
)
attractions_ontology.add_relation(
    Relation(
        label="IN_CITY",
        source="Attraction",
        target="City",
    )
)


model = GeminiGenerativeModel("gemini-1.5-flash-001")
restaurants_kg = KnowledgeGraph(
    name="restaurants",
    ontology=restaurants_ontology,
    model_config=KnowledgeGraphModelConfig.with_model(model),
)
attractions_kg = KnowledgeGraph(
    name="attractions",
    ontology=attractions_ontology,
    model_config=KnowledgeGraphModelConfig.with_model(model),
)


def import_data():
    cities = loads(open("data/cities.json").read())
    restaurants = loads(open("data/restaurants.json").read())
    attractions = loads(open("data/attractions.json").read())

    for city in cities:
        restaurants_kg.add_node(
            "City",
            {
                "name": city["name"],
                "weather": city["weather"],
                "population": city["population"],
            },
        )
        restaurants_kg.add_node("Country", {"name": city["country"]})
        restaurants_kg.add_edge(
            "IN_COUNTRY",
            "City",
            "Country",
            {"name": city["name"]},
            {"name": city["country"]},
        )

        attractions_kg.add_node(
            "City",
            {
                "name": city["name"],
                "weather": city["weather"],
                "population": city["population"],
            },
        )
        attractions_kg.add_node("Country", {"name": city["country"]})
        attractions_kg.add_edge(
            "IN_COUNTRY",
            "City",
            "Country",
            {"name": city["name"]},
            {"name": city["country"]},
        )

    for restaurant in restaurants:
        restaurants_kg.add_node(
            "Restaurant",
            {
                "name": restaurant["name"],
                "description": restaurant["description"],
                "rating": restaurant["rating"],
                "food_type": restaurant["food_type"],
            },
        )
        restaurants_kg.add_edge(
            "IN_CITY",
            "Restaurant",
            "City",
            {"name": restaurant["name"]},
            {"name": restaurant["city"]},
        )

    for attraction in attractions:
        attractions_kg.add_node(
            "Attraction",
            {
                "name": attraction["name"],
                "description": attraction["description"],
                "type": attraction["type"],
            },
        )
        attractions_kg.add_edge(
            "IN_CITY",
            "Attraction",
            "City",
            {"name": attraction["name"]},
            {"name": attraction["city"]},
        )

# %%
import_data()

# %%
restaurants_agent = KGAgent(
    agent_id="restaurants_agent",
    kg=restaurants_kg,
    introduction="""
I'm a restaurant agent, specialized in finding the best restaurants for you. 
""",
)

attractions_agent = KGAgent(
    agent_id="attractions_agent",
    kg=attractions_kg,
    introduction="""
I'm an attractions agent, specialized in finding the best attractions for you. 
""",
)

orchestrator = Orchestrator(model)

orchestrator.register_agent(restaurants_agent)
orchestrator.register_agent(attractions_agent)

runner = orchestrator.ask("Write me a 3 day itinerary for a trip to Italy")
# Out:
# DEBUG:google.auth.transport.requests:Making request: POST https://oauth2.googleapis.com/token
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): oauth2.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://oauth2.googleapis.com:443 "POST /token HTTP/1.1" 200 None
# DEBUG:falkordb_gemini_kg.classes.orchestrator:Execution plan response: ```json
# [{"id": "1", "block": "parallel", "properties": {"steps": [{"id": "1.1", "block": "prompt_agent", "properties": {"agent": "attractions_agent", "prompt": "Suggest 3 attractions for a 3 day trip to Italy."}}, {"id": "1.2", "block": "prompt_agent", "properties": {"agent": "restaurants_agent", "prompt": "Suggest 3 restaurants in Italy."}}]}}, {"id": "2", "block": "summary"}]
# ```
# DEBUG:falkordb_gemini_kg.classes.orchestrator:Execution plan: ExecutionPlan(steps={'steps': [{'id': '1', 'block': 'parallel', 'properties': {'steps': [{'id': '1.1', 'block': 'prompt_agent', 'properties': {'agent': 'attractions_agent', 'prompt': 'Suggest 3 attractions for a 3 day trip to Italy.', 'response': None}}, {'id': '1.2', 'block': 'prompt_agent', 'properties': {'agent': 'restaurants_agent', 'prompt': 'Suggest 3 restaurants in Italy.', 'response': None}}]}}, {'id': '2', 'block': 'summary', 'properties': None}]})

# %%
response = runner.run()
print(response.text)
# Out:
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Cypher Prompt:
# Using the ontology provided, generate an OpenCypher statement to query the graph database returning all relevant entities, relationships, and attributes to answer the question below:
# If you cannot generate a OpenCypher statement for any reason, return an empty string.
# Respect the order of the relationships, the arrows should always point from the "source" to the "target".
#
# Question: Provide a list of top attractions in Italy for a 3 day itinerary.
#
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Cypher Prompt:
# Using the ontology provided, generate an OpenCypher statement to query the graph database returning all relevant entities, relationships, and attributes to answer the question below:
# If you cannot generate a OpenCypher statement for any reason, return an empty string.
# Respect the order of the relationships, the arrows should always point from the "source" to the "target".
#
# Question: Suggest some restaurants in Italy for a 3 day itinerary.
#
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Cypher Statement Response: GenerationResponse(text=```
# MATCH (c:Country {name: "Italy"})<-[:IN_COUNTRY]-(a:Attraction)
# RETURN c, a
# ```, finish_reason=STOP)
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Cypher:
# MATCH (c:Country {name: "Italy"})<-[:IN_COUNTRY]-(a:Attraction)
# RETURN c, a
#
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Error:
#                     Relation IN_COUNTRY does not connect Attraction to Country. Make sure the relation direction is correct.
#                     Valid relations:
#                     (:City)-[:IN_COUNTRY {}]->(:Country)
# (:City)-[:IN_COUNTRY {}]->(:Country)
#
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Cypher Prompt:
# The Cypher statement above failed with the following error:
# "
#                     Relation IN_COUNTRY does not connect Attraction to Country. Make sure the relation direction is correct.
#                     Valid relations:
#                     (:City)-[:IN_COUNTRY {}]->(:Country)
# (:City)-[:IN_COUNTRY {}]->(:Country)
# "
#
# Try to generate a new valid OpenCypher statement.
# Use only the provided entities, relationships types and properties in the ontology.
# The output must be only a valid OpenCypher statement.
# Do not include any apologies or other texts, except the generated OpenCypher statement, enclosed in triple backticks.
#
# Question: Provide a list of top attractions in Italy for a 3 day itinerary.
#
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Cypher Statement Response: GenerationResponse(text=```
# MATCH (c:Country {name: "Italy"})<-[:IN_COUNTRY]-(city:City)-[:IN_CITY]->(r:Restaurant)
# RETURN c, city, r
# ```, finish_reason=STOP)
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Cypher:
# MATCH (c:Country {name: "Italy"})<-[:IN_COUNTRY]-(city:City)-[:IN_CITY]->(r:Restaurant)
# RETURN c, city, r
#
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Error:
#                     Relation IN_CITY does not connect City to Restaurant. Make sure the relation direction is correct.
#                     Valid relations:
#                     (:Restaurant)-[:IN_CITY {}]->(:City)
# (:Attraction)-[:IN_CITY {}]->(:City)
#
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Cypher Prompt:
# The Cypher statement above failed with the following error:
# "
#                     Relation IN_CITY does not connect City to Restaurant. Make sure the relation direction is correct.
#                     Valid relations:
#                     (:Restaurant)-[:IN_CITY {}]->(:City)
# (:Attraction)-[:IN_CITY {}]->(:City)
# "
#
# Try to generate a new valid OpenCypher statement.
# Use only the provided entities, relationships types and properties in the ontology.
# The output must be only a valid OpenCypher statement.
# Do not include any apologies or other texts, except the generated OpenCypher statement, enclosed in triple backticks.
#
# Question: Suggest some restaurants in Italy for a 3 day itinerary.
#
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Cypher Statement Response: GenerationResponse(text=```
# MATCH (c:Country {name: "Italy"})<-[:IN_COUNTRY]-(ci:City)<-[:IN_CITY]-(a:Attraction)
# RETURN c, ci, a
# ```, finish_reason=STOP)
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Cypher:
# MATCH (c:Country {name: "Italy"})<-[:IN_COUNTRY]-(ci:City)<-[:IN_CITY]-(a:Attraction)
# RETURN c, ci, a
#
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Context: [['(:Country{name:"Italy"})', '(:City{name:"Rome",population:2800000,weather:"Mediterranean"})', '(:Attraction{description:"An ancient amphitheater known for gladiatorial contests and public spectacles.",name:"Colosseum",type:"Historical"})'], ['(:Country{name:"Italy"})', '(:City{name:"Rome",population:2800000,weather:"Mediterranean"})', '(:Attraction{description:"A complex of museums and galleries showcasing works of art collected by Popes over centuries.",name:"Vatican Museums",type:"Art"})'], ['(:Country{name:"Italy"})', '(:City{name:"Rome",population:2800000,weather:"Mediterranean"})', '(:Attraction{description:"A Baroque fountain known for its stunning sculptures and tradition of tossing coins.",name:"Trevi Fountain",type:"Landmark"})'], ['(:Country{name:"Italy"})', '(:City{name:"Rome",population:2800000,weather:"Mediterranean"})', '(:Attraction{description:"A major basilica in Rome, known for its rich history and impressive architecture.",name:"Basilica di Santa Maria Maggiore",type:"Religious"})'], ['(:Country{name:"Italy"})', '(:City{name:"Milan",population:1370000,weather:"Humid subtropical"})', '(:Attraction{description:"One of the world\'s most famous opera houses, located in Milan.",name:"Teatro alla Scala",type:"Cultural"})'], ['(:Country{name:"Italy"})', '(:City{name:"Milan",population:1370000,weather:"Humid subtropical"})', '(:Attraction{description:"A historic shopping arcade and a major landmark in Milan, known for its stunning architecture.",name:"Galleria Vittorio Emanuele II",type:"Landmark"})'], ['(:Country{name:"Italy"})', '(:City{name:"Naples",population:967000,weather:"Mediterranean"})', '(:Attraction{description:"A historic palace in Naples, once home to the Bourbon Kings of Naples and Sicily.",name:"Royal Palace of Naples",type:"Historical"})'], ['(:Country{name:"Italy"})', '(:City{name:"Naples",population:967000,weather:"Mediterranean"})', '(:Attraction{description:"The oldest continuously active opera house in the world, located in Naples.",name:"Teatro San Carlo",type:"Cultural"})'], ['(:Country{name:"Italy"})', '(:City{name:"Naples",population:967000,weather:"Mediterranean"})', '(:Attraction{description:"A church in Naples, one of the oldest in the city, featuring Roman and early Christian remains.",name:"San Lorenzo Maggiore",type:"Religious"})'], ['(:Country{name:"Italy"})', '(:City{name:"Turin",population:875000,weather:"Humid subtropical"})', '(:Attraction{description:"A landmark building in Turin known for its towering spire and as the Museum of Cinema.",name:"Mole Antonelliana",type:"Landmark"})'], ['(:Country{name:"Italy"})', '(:City{name:"Turin",population:875000,weather:"Humid subtropical"})', '(:Attraction{description:"A prominent opera house in Turin, known for its rich history and performances.",name:"Teatro Regio",type:"Cultural"})'], ['(:Country{name:"Italy"})', '(:City{name:"Palermo",population:673000,weather:"Mediterranean"})', '(:Attraction{description:"A royal palace in Palermo, originally built in the 9th century.",name:"Palazzo dei Normanni",type:"Historical"})'], ['(:Country{name:"Italy"})', '(:City{name:"Palermo",population:673000,weather:"Mediterranean"})', '(:Attraction{description:"The cathedral church of the Roman Catholic Archdiocese of Palermo, dedicated to the Assumption of the Virgin Mary.",name:"Cattedrale di Palermo",type:"Religious"})'], ['(:Country{name:"Italy"})', '(:City{name:"Palermo",population:673000,weather:"Mediterranean"})', '(:Attraction{description:"A church in Palermo, renowned for its distinctive red domes.",name:"San Giovanni degli Eremiti",type:"Religious"})'], ['(:Country{name:"Italy"})', '(:City{name:"Florence",population:383000,weather:"Temperate"})', '(:Attraction{description:"Florence\'s main cathedral, known for its red-tiled dome designed by Brunelleschi.",name:"Duomo",type:"Religious"})'], ['(:Country{name:"Italy"})', '(:City{name:"Florence",population:383000,weather:"Temperate"})', '(: ...
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Context size: 20
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Context characters: 5094
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Cypher Statement Response: GenerationResponse(text=```
# MATCH (c:Country {name: "Italy"})<-[:IN_COUNTRY]-(city:City)<-[:IN_CITY]-(r:Restaurant)
# RETURN c, city, r
# ```, finish_reason=STOP)
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Cypher:
# MATCH (c:Country {name: "Italy"})<-[:IN_COUNTRY]-(city:City)<-[:IN_CITY]-(r:Restaurant)
# RETURN c, city, r
#
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Context: [['(:Country{name:"Italy"})', '(:City{name:"Rome",population:2800000,weather:"Mediterranean"})', '(:Restaurant{description:"A cozy trattoria known for its traditional Roman dishes and welcoming atmosphere.",food_type:"Italian",name:"Trattoria da Enzo",rating:4.5})'], ['(:Country{name:"Italy"})', '(:City{name:"Rome",population:2800000,weather:"Mediterranean"})', '(:Restaurant{description:"An elegant Michelin-starred restaurant offering contemporary Italian cuisine.",food_type:"Italian",name:"Il Pagliaccio",rating:4.8})'], ['(:Country{name:"Italy"})', '(:City{name:"Milan",population:1370000,weather:"Humid subtropical"})', '(:Restaurant{description:"A popular burger joint in Milan known for its gourmet burgers and relaxed vibe.",food_type:"Burgers",name:"Bros\' Burger",rating:4.3})'], ['(:Country{name:"Italy"})', '(:City{name:"Naples",population:967000,weather:"Mediterranean"})', '(:Restaurant{description:"A renowned seafood restaurant in Naples, offering fresh catch of the day and traditional dishes.",food_type:"Seafood",name:"Il Gambero Rosso",rating:4.5})'], ['(:Country{name:"Italy"})', '(:City{name:"Palermo",population:673000,weather:"Mediterranean"})', '(:Restaurant{description:"A family-run trattoria in Palermo known for its authentic Sicilian cuisine.",food_type:"Sicilian",name:"Da Cimino",rating:4.4})'], ['(:Country{name:"Italy"})', '(:City{name:"Florence",population:383000,weather:"Temperate"})', '(:Restaurant{description:"An upscale restaurant in Florence offering seasonal Tuscan cuisine with a modern twist.",food_type:"Italian",name:"La Bottega del Buon Caffè",rating:4.7})'], ['(:Country{name:"Italy"})', '(:City{name:"Venice",population:260000,weather:"Humid subtropical"})', '(:Restaurant{description:"A charming trattoria in Venice known for its seafood dishes and Venetian specialties.",food_type:"Seafood",name:"Antiche Carampane",rating:4.6})'], ['(:Country{name:"Italy"})', '(:City{name:"Venice",population:260000,weather:"Humid subtropical"})', '(:Restaurant{description:"A historic restaurant in Venice\'s Piazza San Marco, offering gourmet Italian cuisine.",food_type:"Italian",name:"Ristorante Quadri",rating:4.8})']]
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Context size: 8
# DEBUG:falkordb_gemini_kg.steps.graph_query_step:Context characters: 2163
# DEBUG:falkordb_gemini_kg.classes.orchestrator_runner:Execution plan summary: {'steps': [{'id': 'step_1', 'block': 'parallel', 'properties': {'steps': [{'id': 'step_1_1', 'block': 'prompt_agent', 'properties': {'agent': 'attractions_agent', 'prompt': 'Provide a list of top attractions in Italy for a 3 day itinerary.', 'response': "Colosseum, Vatican Museums, Trevi Fountain, Basilica di Santa Maria Maggiore, Teatro alla Scala, Galleria Vittorio Emanuele II, Royal Palace of Naples, Teatro San Carlo, San Lorenzo Maggiore, Mole Antonelliana, Teatro Regio, Palazzo dei Normanni, Cattedrale di Palermo, San Giovanni degli Eremiti, Duomo, Uffizi Gallery, Ponte Vecchio, Grand Canal, St. Mark's Basilica, Rialto Bridge. \n"}}, {'id': 'step_1_2', 'block': 'prompt_agent', 'properties': {'agent': 'restaurants_agent', 'prompt': 'Suggest some restaurants in Italy for a 3 day itinerary.', 'response': "Here are a few restaurant suggestions in Italy for a 3-day itinerary:\n\n* **Rome**: You could try Trattoria da Enzo for traditional Roman dishes, or Il Pagliaccio for contemporary Italian cuisine.\n* **Milan**: For a casual burger experience, consider Bros' Burger.\n* **Naples**: Il Gambero Rosso is a renowned seafood restaurant. \n* **Palermo**: Da Cimino is a family-run trattoria serving authentic Sicilian food. \n"}}]}}, {'id': 'step_2', 'block': 'summary', 'properties': None}]}
# ## 3-Day Itinerary for Italy:
#
# **Day 1:**
#
# * **Morning:** Visit the Colosseum in Rome, followed by a tour of the Vatican Museums.
# * **Afternoon:** Enjoy a leisurely lunch at Trattoria da Enzo in Rome, then explore the Trevi Fountain.
# * **Evening:** Have dinner at Il Pagliaccio in Rome and stroll through the vibrant Piazza Navona.
#
# **Day 2:**
#
# * **Morning:** Take a high-speed train to Milan and visit the Galleria Vittorio Emanuele II.
# * **Afternoon:**  Have lunch at Bros' Burger in Milan and visit the Teatro alla Scala.
# * **Evening:** Enjoy a delicious dinner at Il Gambero Rosso in Naples and experience the city's lively nightlife.
#
# **Day 3:**
#
# * **Morning:** Explore the historical center of Palermo, visiting the Cattedrale di Palermo and the Palazzo dei Normanni.
# * **Afternoon:** Enjoy a traditional Sicilian lunch at Da Cimino in Palermo.
# * **Evening:** Take a leisurely stroll through the historic district of Venice, admiring the Doge's Palace, St. Mark's Basilica, and the Rialto Bridge.
#
# This itinerary provides a great overview of some of the most popular attractions and dining options in Italy.  Remember to book your transportation and accommodations in advance, especially if you are traveling during peak season. Enjoy your trip!
