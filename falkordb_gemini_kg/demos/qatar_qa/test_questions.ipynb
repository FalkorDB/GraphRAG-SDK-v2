# %%
from dotenv import load_dotenv

load_dotenv()
from openai import OpenAI
import json

# %%
openai = OpenAI()

with open("data/animals.txt", "r") as f:
    raw = f.readlines()
    print(len(raw))

i = 0
data = []
for line in raw:
    l = json.loads(line)
    data.append({})
    data[i]["id"] = i
    data[i]["question"] = l["anchor"]
    data[i]["answer"] = l["positive"]
    i += 1
# Out:
# 356

# %%
SYSTEM = "You are a ontologist specialist. You have the skills to identify and extract any entities and relations between any pieces of data."

PROMPT = """
Task: Given the following questions and answers, extract the entities found in all of them. Try to keep it synthetic, general, and simple.

The output format should be a json object list with the following structure:
{{
  id: {{ question_id }}, entities: {{ entity_list }}
}}

Example:
input: {{"id": 0, "anchor": "What is the policy for carrying a falcon on Qatar Airways?", "positive": "Yes falcon can be carried only when traveling in economy class. After the booking is completed. Kindly visit the link below to place the request https://www.qatarairways.com/en/help.html?iid=ALL75199970#avih", "category": "animals", "keyword": "falcon"}}
output: {{"id": 0, "entities": ["falcon", "Qatar Airways", "policy", "economy class", "booking", "link", "request"]}}

Data:

{data}
"""

# %%
responses = [
    openai.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": SYSTEM},
            {"role": "user", "content": PROMPT.format(data=json.dumps(line))},
        ],
    )
    for line in data
]

# %%
import re

data = [
     r.choices[0].message.content
    for r in responses
]

# ['```json\n[\n  {\n    "id": 0,\n    "entities": ["policy", "falcon", "Qatar Airways", "economy class", "booking", "request"]\n  }\n]\n```',

parsed = [
    re.findall(r'\"(.*?)\"', d)
    for d in data
]

# set

# %%
entities = set()
for p in parsed:
    entities.update(p)

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain_openai import ChatOpenAI
import concurrent
from langchain.docstore.document import Document
from concurrent.futures import ThreadPoolExecutor

llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0,
)


llm_transformer = LLMGraphTransformer(
    llm=llm,
    node_properties=True,
    allowed_nodes=["pet", "fee", "geo", "policy", "question", "answer"],
    allowed_relationships=[],
)
futures = []
graph_document_list = []
combined_chunk_document_list = data
def run_graph():
    with ThreadPoolExecutor(max_workers=10) as executor:
        for chunk in combined_chunk_document_list:
            chunk_doc = Document(
                page_content=json.dumps(chunk)
            )
            futures.append(
                executor.submit(llm_transformer.convert_to_graph_documents, [chunk_doc])
            )

        for i, future in enumerate(concurrent.futures.as_completed(futures)):
            graph_document = future.result()
            graph_document_list.append(graph_document[0])


run_graph()

# %%
graph_document_list
# Out:
# [GraphDocument(nodes=[Node(id='9', type='Question', properties={'text': 'How much does it cost to transport a falcon from Europe to the Americas?'}), Node(id='9_Answer', type='Answer', properties={'text': 'The cost to transport a falcon from Europe to the Americas is 630 USD (CAD 820).'})], relationships=[Relationship(source=Node(id='9', type='Question'), target=Node(id='9_Answer', type='Answer'), type='ANSWER')], source=Document(page_content='{"id": 9, "question": "How much does it cost to transport a falcon from Europe to the Americas?", "answer": "The cost to transport a falcon from Europe to the Americas is 630 USD (CAD 820)."}')),
#  GraphDocument(nodes=[Node(id='What Is The Policy For Carrying A Falcon On Qatar Airways?', type='Question'), Node(id='Yes Falcon Can Be Carried Only When Traveling In Economy Class. After The Booking Is Completed. Kindly Visit The Link Below To Place The Request Https://Www.Qatarairways.Com/En/Help.Html?Iid=All75199970#Avih', type='Answer')], relationships=[Relationship(source=Node(id='What Is The Policy For Carrying A Falcon On Qatar Airways?', type='Question'), target=Node(id='Yes Falcon Can Be Carried Only When Traveling In Economy Class. After The Booking Is Completed. Kindly Visit The Link Below To Place The Request Https://Www.Qatarairways.Com/En/Help.Html?Iid=All75199970#Avih', type='Answer'), type='ANSWER')], source=Document(page_content='{"id": 0, "question": "What is the policy for carrying a falcon on Qatar Airways?", "answer": "Yes falcon can be carried only when traveling in economy class. After the booking is completed. Kindly visit the link below to place the request https://www.qatarairways.com/en/help.html?iid=ALL75199970#avih"}')),
#  GraphDocument(nodes=[Node(id='5', type='Question', properties={'text': 'How much does it cost to transport a falcon from Africa to the Americas?'}), Node(id='Cost_Transport_Falcon', type='Answer', properties={'text': 'The cost to transport a falcon from Africa to the Americas is 630 USD (CAD 820).'})], relationships=[Relationship(source=Node(id='5', type='Question'), target=Node(id='Cost_Transport_Falcon', type='Answer'), type='ANSWER')], source=Document(page_content='{"id": 5, "question": "How much does it cost to transport a falcon from Africa to the Americas?", "answer": "The cost to transport a falcon from Africa to the Americas is 630 USD (CAD 820)."}')),
#  GraphDocument(nodes=[Node(id='What Is The Price To Transport A Falcon From Africa To Qatar?', type='Question'), Node(id='The Price To Transport A Falcon From Africa To Qatar Is 240 Usd.', type='Answer'), Node(id='Africa', type='Geo'), Node(id='Qatar', type='Geo'), Node(id='Falcon', type='Pet'), Node(id='240 Usd', type='Fee')], relationships=[Relationship(source=Node(id='What Is The Price To Transport A Falcon From Africa To Qatar?', type='Question'), target=Node(id='The Price To Transport A Falcon From Africa To Qatar Is 240 Usd.', type='Answer'), type='ANSWER'), Relationship(source=Node(id='Falcon', type='Pet'), target=Node(id='240 Usd', type='Fee'), type='TRANSPORT_FEE'), Relationship(source=Node(id='Africa', type='Geo'), target=Node(id='Qatar', type='Geo'), type='TO')], source=Document(page_content='{"id": 4, "question": "What is the price to transport a falcon from Africa to Qatar?", "answer": "The price to transport a falcon from Africa to Qatar is 240 USD."}')),
#  GraphDocument(nodes=[Node(id='6', type='Question', properties={'text': 'What is the price to transport a falcon from Europe to Africa?'}), Node(id='Price_Transport_Falcon_Europe_Africa', type='Answer', properties={'text': 'The price to transport a falcon from Europe to Africa is 450 USD.'}), Node(id='Europe', type='Geo'), Node(id='Africa', type='Geo'), Node(id='Falcon', type='Pet'), Node(id='450 Usd', type='Fee')], relationships=[Relationship(source=Node(id='6', type='Question'), target=Node(id='Price_Transport_Falcon_Europe_Africa', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Price_Transport_Falcon_Europe_Africa', type='Answer'), target=Node(id='Europe', type='Geo'), type='FROM'), Relationship(source=Node(id='Price_Transport_Falcon_Europe_Africa', type='Answer'), target=Node(id='Africa', type='Geo'), type='TO'), Relationship(source=Node(id='Price_Transport_Falcon_Europe_Africa', type='Answer'), target=Node(id='Falcon', type='Pet'), type='SUBJECT'), Relationship(source=Node(id='Price_Transport_Falcon_Europe_Africa', type='Answer'), target=Node(id='450 Usd', type='Fee'), type='COST')], source=Document(page_content='{"id": 6, "question": "What is the price to transport a falcon from Europe to Africa?", "answer": "The price to transport a falcon from Europe to Africa is 450 USD."}')),
#  GraphDocument(nodes=[Node(id='1', type='Question', properties={'text': 'What is the price to transport a falcon from Africa to Europe?'}), Node(id='Price_Transport_Falcon', type='Answer', properties={'text': 'The price to transport a falcon from Africa to Europe is 450 USD.'}), Node(id='Falcon', type='Pet'), Node(id='Africa', type='Geo'), Node(id='Europe', type='Geo'), Node(id='450 Usd', type='Fee')], relationships=[Relationship(source=Node(id='1', type='Question'), target=Node(id='Price_Transport_Falcon', type='Answer'), type='ANSWER'), Relationship(source=Node(id='Price_Transport_Falcon', type='Answer'), target=Node(id='Falcon', type='Pet'), type='SUBJECT'), Relationship(source=Node(id='Price_Transport_Falcon', type='Answer'), target=Node(id='Africa', type='Geo'), type='ORIGIN'), Relationship(source=Node(id='Price_Transport_Falcon', type='Answer'), target=Node(id='Europe', type='Geo'), type='DESTINATION'), Relationship(source=Node(id='Price_Transport_Falcon', type='Answer'), target=Node(id='450 Usd', type='Fee'), type='COST')], source=Document(page_content='{"id": 1, "question": "What is the price to transport a falcon from Africa to Europe?", "answer": "The price to transport a falcon from Africa to Europe is 450 USD."}')),
#  GraphDocument(nodes=[Node(id='What Is The Price To Transport A Falcon From The Far East To Africa?', type='Question'), Node(id='The Price To Transport A Falcon From The Far East To Africa Is 450 Usd.', type='Answer')], relationships=[Relationship(source=Node(id='What Is The Price To Transport A Falcon From The Far East To Africa?', type='Question'), target=Node(id='The Price To Transport A Falcon From The Far East To Africa Is 450 Usd.', type='Answer'), type='ANSWER')], source=Document(page_content='{"id": 10, "question": "What is the price to transport a falcon from the Far East to Africa?", "answer": "The price to transport a falcon from the Far East to Africa is 450 USD."}')),
#  GraphDocument(nodes=[Node(id='11', type='Question', properties={'text': 'Can I transport falcons in Economy Class?'}), Node(id='Answer_11', type='Answer', properties={'text': 'Yes, you can transport falcons in Economy Class on Qatar Airways.'})], relationships=[Relationship(source=Node(id='11', type='Question'), target=Node(id='Answer_11', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 11, "question": "Can I transport falcons in Economy Class?", "answer": "Yes, you can transport falcons in Economy Class on Qatar Airways."}')),
#  GraphDocument(nodes=[Node(id='3', type='Question', properties={'text': 'What is the price for transporting a falcon from Africa to the Middle East and Indian sub-continent?'}), Node(id='Price_Transport_Falcon', type='Answer', properties={'text': 'The price for transporting a falcon from Africa to the Middle East and Indian sub-continent is 270 USD.'}), Node(id='Falcon', type='Pet'), Node(id='Africa', type='Geo'), Node(id='Middle East', type='Geo'), Node(id='Indian Sub-Continent', type='Geo'), Node(id='270 Usd', type='Fee')], relationships=[Relationship(source=Node(id='3', type='Question'), target=Node(id='Price_Transport_Falcon', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Price_Transport_Falcon', type='Answer'), target=Node(id='Falcon', type='Pet'), type='MENTIONS'), Relationship(source=Node(id='Price_Transport_Falcon', type='Answer'), target=Node(id='Africa', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Price_Transport_Falcon', type='Answer'), target=Node(id='Middle East', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Price_Transport_Falcon', type='Answer'), target=Node(id='Indian Sub-Continent', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Price_Transport_Falcon', type='Answer'), target=Node(id='270 Usd', type='Fee'), type='MENTIONS')], source=Document(page_content='{"id": 3, "question": "What is the price for transporting a falcon from Africa to the Middle East and Indian sub-continent?", "answer": "The price for transporting a falcon from Africa to the Middle East and Indian sub-continent is 270 USD."}')),
#  GraphDocument(nodes=[Node(id='7', type='Question', properties={'text': 'How much does it cost to transport a falcon from Europe to the Middle East and Indian sub-continent?'}), Node(id='Answer_7', type='Answer', properties={'text': 'The cost to transport a falcon from Europe to the Middle East and Indian sub-continent is 270 USD.'}), Node(id='Falcon', type='Pet'), Node(id='Europe', type='Geo'), Node(id='Middle East', type='Geo'), Node(id='Indian Sub-Continent', type='Geo'), Node(id='270 Usd', type='Fee')], relationships=[Relationship(source=Node(id='7', type='Question'), target=Node(id='Answer_7', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Answer_7', type='Answer'), target=Node(id='Falcon', type='Pet'), type='MENTIONS'), Relationship(source=Node(id='Answer_7', type='Answer'), target=Node(id='Europe', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Answer_7', type='Answer'), target=Node(id='Middle East', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Answer_7', type='Answer'), target=Node(id='Indian Sub-Continent', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Answer_7', type='Answer'), target=Node(id='270 Usd', type='Fee'), type='MENTIONS')], source=Document(page_content='{"id": 7, "question": "How much does it cost to transport a falcon from Europe to the Middle East and Indian sub-continent?", "answer": "The cost to transport a falcon from Europe to the Middle East and Indian sub-continent is 270 USD."}')),
#  GraphDocument(nodes=[Node(id='8', type='Question', properties={'text': 'What is the price for transporting a falcon from Europe to Qatar?'}), Node(id='Price_Transporting_Falcon', type='Answer', properties={'text': 'The price for transporting a falcon from Europe to Qatar is 240 USD.'}), Node(id='Falcon', type='Pet'), Node(id='Europe', type='Geo'), Node(id='Qatar', type='Geo'), Node(id='240_Usd', type='Fee')], relationships=[Relationship(source=Node(id='8', type='Question'), target=Node(id='Price_Transporting_Falcon', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Price_Transporting_Falcon', type='Answer'), target=Node(id='Falcon', type='Pet'), type='MENTIONS'), Relationship(source=Node(id='Price_Transporting_Falcon', type='Answer'), target=Node(id='Europe', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Price_Transporting_Falcon', type='Answer'), target=Node(id='Qatar', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Price_Transporting_Falcon', type='Answer'), target=Node(id='240_Usd', type='Fee'), type='MENTIONS')], source=Document(page_content='{"id": 8, "question": "What is the price for transporting a falcon from Europe to Qatar?", "answer": "The price for transporting a falcon from Europe to Qatar is 240 USD."}')),
#  GraphDocument(nodes=[Node(id='2', type='Question', properties={'text': 'How much does it cost to transport a falcon from Africa to Australia, New Zealand, Japan, and South Korea?'}), Node(id='Cost_Transport_Falcon', type='Answer', properties={'text': 'The cost to transport a falcon from Africa to Australia, New Zealand, Japan, and South Korea is 630 USD.'}), Node(id='Africa', type='Geo'), Node(id='Australia', type='Geo'), Node(id='New Zealand', type='Geo'), Node(id='Japan', type='Geo'), Node(id='South Korea', type='Geo')], relationships=[Relationship(source=Node(id='2', type='Question'), target=Node(id='Cost_Transport_Falcon', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Cost_Transport_Falcon', type='Answer'), target=Node(id='Africa', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Cost_Transport_Falcon', type='Answer'), target=Node(id='Australia', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Cost_Transport_Falcon', type='Answer'), target=Node(id='New Zealand', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Cost_Transport_Falcon', type='Answer'), target=Node(id='Japan', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Cost_Transport_Falcon', type='Answer'), target=Node(id='South Korea', type='Geo'), type='MENTIONS')], source=Document(page_content='{"id": 2, "question": "How much does it cost to transport a falcon from Africa to Australia, New Zealand, Japan, and South Korea?", "answer": "The cost to transport a falcon from Africa to Australia, New Zealand, Japan, and South Korea is 630 USD."}')),
#  GraphDocument(nodes=[Node(id='What Is The Cost Of Transporting A Falcon From Africa To Qatar?', type='Question'), Node(id='The Cost Of Transporting A Falcon From Africa To Qatar Is 240 Usd.', type='Answer')], relationships=[Relationship(source=Node(id='What Is The Cost Of Transporting A Falcon From Africa To Qatar?', type='Question'), target=Node(id='The Cost Of Transporting A Falcon From Africa To Qatar Is 240 Usd.', type='Answer'), type='ANSWER_TO')], source=Document(page_content='{"id": 15, "question": "What is the cost of transporting a falcon from Africa to Qatar?", "answer": "The cost of transporting a falcon from Africa to Qatar is 240 USD."}')),
#  GraphDocument(nodes=[Node(id='14', type='Question', properties={'text': 'Do falcon transportation rates change based on the destination?'}), Node(id='14_Answer', type='Answer', properties={'text': 'Yes, falcon transportation rates vary based on the destination. Different rates apply for different regions.'})], relationships=[Relationship(source=Node(id='14', type='Question'), target=Node(id='14_Answer', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 14, "question": "Do falcon transportation rates change based on the destination?", "answer": "Yes, falcon transportation rates vary based on the destination. Different rates apply for different regions."}')),
#  GraphDocument(nodes=[Node(id='12', type='Question', properties={'text': 'How much does it cost to transport a falcon from Africa to Europe?'}), Node(id='Cost_Transport_Falcon', type='Answer', properties={'text': 'The cost to transport a falcon from Africa to Europe is 450 USD.'}), Node(id='Africa', type='Geo'), Node(id='Europe', type='Geo'), Node(id='Falcon', type='Pet')], relationships=[Relationship(source=Node(id='12', type='Question'), target=Node(id='Cost_Transport_Falcon', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Cost_Transport_Falcon', type='Answer'), target=Node(id='Africa', type='Geo'), type='FROM'), Relationship(source=Node(id='Cost_Transport_Falcon', type='Answer'), target=Node(id='Europe', type='Geo'), type='TO'), Relationship(source=Node(id='Cost_Transport_Falcon', type='Answer'), target=Node(id='Falcon', type='Pet'), type='SUBJECT')], source=Document(page_content='{"id": 12, "question": "How much does it cost to transport a falcon from Africa to Europe?", "answer": "The cost to transport a falcon from Africa to Europe is 450 USD."}')),
#  GraphDocument(nodes=[Node(id='17', type='Question', properties={'text': 'Are there any specific restrictions or guidelines for transporting falcons?'}), Node(id='17_Answer', type='Answer', properties={'text': 'The text does not mention any specific restrictions or guidelines for transporting falcons. Please check with Qatar Airways for any applicable guidelines.'})], relationships=[Relationship(source=Node(id='17', type='Question'), target=Node(id='17_Answer', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 17, "question": "Are there any specific restrictions or guidelines for transporting falcons?", "answer": "The text does not mention any specific restrictions or guidelines for transporting falcons. Please check with Qatar Airways for any applicable guidelines."}')),
#  GraphDocument(nodes=[Node(id='What Is The Price To Transport A Falcon Within The Far East Region?', type='Question'), Node(id='The Price To Transport A Falcon Within The Far East Region Is 450 Usd.', type='Answer')], relationships=[Relationship(source=Node(id='What Is The Price To Transport A Falcon Within The Far East Region?', type='Question'), target=Node(id='The Price To Transport A Falcon Within The Far East Region Is 450 Usd.', type='Answer'), type='ANSWER_TO')], source=Document(page_content='{"id": 18, "question": "What is the price to transport a falcon within the Far East region?", "answer": "The price to transport a falcon within the Far East region is 450 USD."}')),
#  GraphDocument(nodes=[Node(id='20', type='Question', properties={'text': 'What are the rates for transporting falcons from Africa to Australia, New Zealand, Japan, and South Korea?'}), Node(id='20_Answer', type='Answer', properties={'text': 'The rates for transporting falcons from Africa to Australia, New Zealand, Japan, and South Korea are 630 USD.'})], relationships=[Relationship(source=Node(id='20', type='Question'), target=Node(id='20_Answer', type='Answer'), type='ANSWER_TO')], source=Document(page_content='{"id": 20, "question": "What are the rates for transporting falcons from Africa to Australia, New Zealand, Japan, and South Korea?", "answer": "The rates for transporting falcons from Africa to Australia, New Zealand, Japan, and South Korea are 630 USD."}')),
#  GraphDocument(nodes=[Node(id='13', type='Question', properties={'text': 'What is the price to transport a falcon from Europe to Australia?'}), Node(id='Price_Transport_Falcon', type='Answer', properties={'text': 'The price to transport a falcon from Europe to Australia is 630 USD.'}), Node(id='Falcon', type='Pet'), Node(id='Europe', type='Geo'), Node(id='Australia', type='Geo'), Node(id='630 Usd', type='Fee')], relationships=[Relationship(source=Node(id='13', type='Question'), target=Node(id='Price_Transport_Falcon', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Price_Transport_Falcon', type='Answer'), target=Node(id='Falcon', type='Pet'), type='MENTIONS'), Relationship(source=Node(id='Price_Transport_Falcon', type='Answer'), target=Node(id='Europe', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Price_Transport_Falcon', type='Answer'), target=Node(id='Australia', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Price_Transport_Falcon', type='Answer'), target=Node(id='630 Usd', type='Fee'), type='MENTIONS')], source=Document(page_content='{"id": 13, "question": "What is the price to transport a falcon from Europe to Australia?", "answer": "The price to transport a falcon from Europe to Australia is 630 USD."}')),
#  GraphDocument(nodes=[Node(id='21', type='Question', properties={'text': 'Can I transport my falcon in Economy Class?'}), Node(id='Qatar Airways', type='Policy', properties={'text': 'Qatar Airways allows the transportation of falcons in Economy Class.'}), Node(id='Falcon', type='Pet')], relationships=[Relationship(source=Node(id='21', type='Question'), target=Node(id='Qatar Airways', type='Policy'), type='ANSWERED_BY'), Relationship(source=Node(id='Qatar Airways', type='Policy'), target=Node(id='Falcon', type='Pet'), type='ALLOWS_TRANSPORTATION_OF')], source=Document(page_content='{"id": 21, "question": "Can I transport my falcon in Economy Class?", "answer": "Yes, Qatar Airways allows the transportation of falcons in Economy Class."}')),
#  GraphDocument(nodes=[Node(id='How Much Does It Cost To Transport A Falcon From Africa To Qatar?', type='Question'), Node(id='The Cost For Transporting A Falcon From Africa To Qatar Is 240 Usd.', type='Answer')], relationships=[Relationship(source=Node(id='How Much Does It Cost To Transport A Falcon From Africa To Qatar?', type='Question'), target=Node(id='The Cost For Transporting A Falcon From Africa To Qatar Is 240 Usd.', type='Answer'), type='ANSWER')], source=Document(page_content='{"id": 25, "question": "How much does it cost to transport a falcon from Africa to Qatar?", "answer": "The cost for transporting a falcon from Africa to Qatar is 240 USD."}')),
#  GraphDocument(nodes=[Node(id='19', type='Question', properties={'text': 'Can I transport a falcon from Europe to the Middle East?'}), Node(id='Answer_19', type='Answer', properties={'text': 'Yes, you can transport a falcon from Europe to the Middle East. The cost is 270 USD.'}), Node(id='Europe', type='Geo'), Node(id='Middle East', type='Geo'), Node(id='Falcon', type='Pet'), Node(id='270 Usd', type='Fee')], relationships=[Relationship(source=Node(id='19', type='Question'), target=Node(id='Answer_19', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Answer_19', type='Answer'), target=Node(id='Europe', type='Geo'), type='FROM'), Relationship(source=Node(id='Answer_19', type='Answer'), target=Node(id='Middle East', type='Geo'), type='TO'), Relationship(source=Node(id='Answer_19', type='Answer'), target=Node(id='Falcon', type='Pet'), type='TRANSPORT'), Relationship(source=Node(id='Answer_19', type='Answer'), target=Node(id='270 Usd', type='Fee'), type='COST')], source=Document(page_content='{"id": 19, "question": "Can I transport a falcon from Europe to the Middle East?", "answer": "Yes, you can transport a falcon from Europe to the Middle East. The cost is 270 USD."}')),
#  GraphDocument(nodes=[Node(id='16', type='Question', properties={'text': 'Can a falcon be transported from Europe to the Americas?'}), Node(id='Answer_16', type='Answer', properties={'text': 'Yes, a falcon can be transported from Europe to the Americas. The cost is 630 USD (CAD 820).'}), Node(id='Falcon', type='Pet'), Node(id='Europe', type='Geo'), Node(id='Americas', type='Geo'), Node(id='630 Usd', type='Fee'), Node(id='820 Cad', type='Fee')], relationships=[Relationship(source=Node(id='16', type='Question'), target=Node(id='Answer_16', type='Answer'), type='ANSWERED_BY'), Relationship(source=Node(id='Falcon', type='Pet'), target=Node(id='Europe', type='Geo'), type='ORIGIN'), Relationship(source=Node(id='Falcon', type='Pet'), target=Node(id='Americas', type='Geo'), type='DESTINATION'), Relationship(source=Node(id='Falcon', type='Pet'), target=Node(id='630 Usd', type='Fee'), type='COST'), Relationship(source=Node(id='Falcon', type='Pet'), target=Node(id='820 Cad', type='Fee'), type='COST')], source=Document(page_content='{"id": 16, "question": "Can a falcon be transported from Europe to the Americas?", "answer": "Yes, a falcon can be transported from Europe to the Americas. The cost is 630 USD (CAD 820)."}')),
#  GraphDocument(nodes=[Node(id='26', type='Question', properties={'text': 'Are there any additional charges for transporting falcons from Africa to The Americas?'}), Node(id='26_Answer', type='Answer', properties={'text': 'Yes, there are additional charges for transporting falcons from Africa to The Americas. The cost is 630 USD (CAD 820).'})], relationships=[Relationship(source=Node(id='26', type='Question'), target=Node(id='26_Answer', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 26, "question": "Are there any additional charges for transporting falcons from Africa to The Americas?", "answer": "Yes, there are additional charges for transporting falcons from Africa to The Americas. The cost is 630 USD (CAD 820)."}')),
#  GraphDocument(nodes=[Node(id='27', type='Question', properties={'text': 'What is the rate for transporting falcons from Europe to Africa?'}), Node(id='Rate_Transporting_Falcons', type='Answer', properties={'text': 'The rate for transporting falcons from Europe to Africa is 450 USD.'})], relationships=[Relationship(source=Node(id='27', type='Question'), target=Node(id='Rate_Transporting_Falcons', type='Answer'), type='ANSWER')], source=Document(page_content='{"id": 27, "question": "What is the rate for transporting falcons from Europe to Africa?", "answer": "The rate for transporting falcons from Europe to Africa is 450 USD."}')),
#  GraphDocument(nodes=[Node(id='22', type='Question', properties={'text': 'What are the rates for transporting falcons from Africa to Europe?'}), Node(id='Rates_For_Transporting_Falcons', type='Answer', properties={'text': 'The rates for transporting falcons from Africa to Europe is 450 USD.'}), Node(id='Africa', type='Geo'), Node(id='Europe', type='Geo')], relationships=[Relationship(source=Node(id='22', type='Question'), target=Node(id='Rates_For_Transporting_Falcons', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Rates_For_Transporting_Falcons', type='Answer'), target=Node(id='Africa', type='Geo'), type='FROM'), Relationship(source=Node(id='Rates_For_Transporting_Falcons', type='Answer'), target=Node(id='Europe', type='Geo'), type='TO')], source=Document(page_content='{"id": 22, "question": "What are the rates for transporting falcons from Africa to Europe?", "answer": "The rates for transporting falcons from Africa to Europe is 450 USD."}')),
#  GraphDocument(nodes=[Node(id='24', type='Question', properties={'text': 'What is the rate for transporting falcons from Africa to The Middle East or Indian sub-continent?'}), Node(id='Rate_Transporting_Falcons', type='Answer', properties={'text': 'The rate for transporting falcons from Africa to The Middle East or Indian sub-continent is 270 USD.'}), Node(id='Africa', type='Geo'), Node(id='The Middle East', type='Geo'), Node(id='Indian Sub-Continent', type='Geo')], relationships=[Relationship(source=Node(id='24', type='Question'), target=Node(id='Rate_Transporting_Falcons', type='Answer'), type='ANSWERED_BY'), Relationship(source=Node(id='Rate_Transporting_Falcons', type='Answer'), target=Node(id='Africa', type='Geo'), type='FROM'), Relationship(source=Node(id='Rate_Transporting_Falcons', type='Answer'), target=Node(id='The Middle East', type='Geo'), type='TO'), Relationship(source=Node(id='Rate_Transporting_Falcons', type='Answer'), target=Node(id='Indian Sub-Continent', type='Geo'), type='TO')], source=Document(page_content='{"id": 24, "question": "What is the rate for transporting falcons from Africa to The Middle East or Indian sub-continent?", "answer": "The rate for transporting falcons from Africa to The Middle East or Indian sub-continent is 270 USD."}')),
#  GraphDocument(nodes=[Node(id='30', type='Question', properties={'text': 'What is the rate for transporting falcons from Europe to The Middle East or Indian sub-continent?'}), Node(id='Rate_Transporting_Falcons', type='Answer', properties={'text': 'The rate for transporting falcons from Europe to The Middle East or Indian sub-continent is 270 USD.'})], relationships=[Relationship(source=Node(id='30', type='Question'), target=Node(id='Rate_Transporting_Falcons', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 30, "question": "What is the rate for transporting falcons from Europe to The Middle East or Indian sub-continent?", "answer": "The rate for transporting falcons from Europe to The Middle East or Indian sub-continent is 270 USD."}')),
#  GraphDocument(nodes=[Node(id='32', type='Question', properties={'text': 'Can I bring my pet on board?'}), Node(id='Answer_32', type='Answer', properties={'text': 'Yes, you can bring your pet on board. Please refer to our terms and conditions for traveling with animals.'})], relationships=[Relationship(source=Node(id='32', type='Question'), target=Node(id='Answer_32', type='Answer'), type='ANSWERED_BY')], source=Document(page_content='{"id": 32, "question": "Can I bring my pet on board?", "answer": "Yes, you can bring your pet on board. Please refer to our terms and conditions for traveling with animals."}')),
#  GraphDocument(nodes=[Node(id='31', type='Question', properties={'text': 'What are the terms and conditions for traveling with animals?'}), Node(id='31_Answer', type='Answer', properties={'text': 'The terms and conditions for traveling with animals are not mentioned in the provided text.'})], relationships=[Relationship(source=Node(id='31', type='Question'), target=Node(id='31_Answer', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 31, "question": "What are the terms and conditions for traveling with animals?", "answer": "The terms and conditions for traveling with animals are not mentioned in the provided text."}')),
#  GraphDocument(nodes=[Node(id='33', type='Question', properties={'text': 'What are the terms and conditions for traveling with Falcons?'}), Node(id='Answer_33', type='Answer', properties={'text': 'Unfortunately, the provided text does not mention the terms and conditions for traveling with Falcons. For more information, please reach out to Qatar Airways directly.'})], relationships=[Relationship(source=Node(id='33', type='Question'), target=Node(id='Answer_33', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 33, "question": "What are the terms and conditions for traveling with Falcons?", "answer": "Unfortunately, the provided text does not mention the terms and conditions for traveling with Falcons. For more information, please reach out to Qatar Airways directly."}')),
#  GraphDocument(nodes=[Node(id='35', type='Question', properties={'text': 'Can I transport falcons in the Economy Class cabin?'}), Node(id='Answer_35', type='Answer', properties={'text': 'Yes, you can transport falcons in the Economy Class cabin. However, please note that rates may apply for transporting falcons.'})], relationships=[Relationship(source=Node(id='35', type='Question'), target=Node(id='Answer_35', type='Answer'), type='ANSWERED_BY')], source=Document(page_content='{"id": 35, "question": "Can I transport falcons in the Economy Class cabin?", "answer": "Yes, you can transport falcons in the Economy Class cabin. However, please note that rates may apply for transporting falcons."}')),
#  GraphDocument(nodes=[Node(id='34', type='Question', properties={'text': 'What are the terms and conditions for travelling with Falcons?'}), Node(id='Terms_And_Conditions_Travelling_With_Falcons', type='Answer', properties={'text': 'The rates in Qatari Riyals (QAR) apply only when additional baggage is purchased in Qatar for travel originating from Doha.'})], relationships=[Relationship(source=Node(id='34', type='Question'), target=Node(id='Terms_And_Conditions_Travelling_With_Falcons', type='Answer'), type='ANSWER')], source=Document(page_content='{"id": 34, "question": "What are the terms and conditions for travelling with Falcons?", "answer": "The rates in Qatari Riyals (QAR) apply only when additional baggage is purchased in Qatar for travel originating from Doha."}')),
#  GraphDocument(nodes=[Node(id='36', type='Question', properties={'text': 'Are changes permitted for falcon transportation?'}), Node(id='Answer_36', type='Answer', properties={'text': 'Yes, changes are permitted free of charge for falcon transportation.'})], relationships=[Relationship(source=Node(id='36', type='Question'), target=Node(id='Answer_36', type='Answer'), type='ANSWERED_BY')], source=Document(page_content='{"id": 36, "question": "Are changes permitted for falcon transportation?", "answer": "Yes, changes are permitted free of charge for falcon transportation."}')),
#  GraphDocument(nodes=[Node(id='Can I Transport My Falcon From Europe To Europe?', type='Question'), Node(id='Yes, Qatar Airways Allows The Transportation Of Falcons From Europe To Europe. The Rate Is 450 Usd.', type='Answer'), Node(id='Europe', type='Geo'), Node(id='Falcon', type='Pet'), Node(id='450 Usd', type='Fee'), Node(id='Qatar Airways', type='Policy')], relationships=[Relationship(source=Node(id='Can I Transport My Falcon From Europe To Europe?', type='Question'), target=Node(id='Yes, Qatar Airways Allows The Transportation Of Falcons From Europe To Europe. The Rate Is 450 Usd.', type='Answer'), type='ANSWER'), Relationship(source=Node(id='Qatar Airways', type='Policy'), target=Node(id='Falcon', type='Pet'), type='TRANSPORTATION'), Relationship(source=Node(id='Qatar Airways', type='Policy'), target=Node(id='Europe', type='Geo'), type='FROM'), Relationship(source=Node(id='Qatar Airways', type='Policy'), target=Node(id='Europe', type='Geo'), type='TO'), Relationship(source=Node(id='Qatar Airways', type='Policy'), target=Node(id='450 Usd', type='Fee'), type='RATE')], source=Document(page_content='{"id": 28, "question": "Can I transport my falcon from Europe to Europe?", "answer": "Yes, Qatar Airways allows the transportation of falcons from Europe to Europe. The rate is 450 USD."}')),
#  GraphDocument(nodes=[Node(id='37', type='Question', properties={'text': 'Can I carry falcons in the passenger cabin on flights to/from Tunis?'}), Node(id='Answer_37', type='Answer', properties={'text': 'No, the carriage of falcons within the passenger cabin of a Qatar Airways aircraft is not permitted on flights to/from Tunis.'})], relationships=[Relationship(source=Node(id='37', type='Question'), target=Node(id='Answer_37', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 37, "question": "Can I carry falcons in the passenger cabin on flights to/from Tunis?", "answer": "No, the carriage of falcons within the passenger cabin of a Qatar Airways aircraft is not permitted on flights to/from Tunis."}')),
#  GraphDocument(nodes=[Node(id='38', type='Question', properties={'text': 'Is cancellation allowed for falcon transportation?'}), Node(id='Answer_38', type='Answer', properties={'text': 'Yes, cancellation is allowed free of charge for falcon transportation. The residual value can be issued for further transportation or refund.'})], relationships=[Relationship(source=Node(id='38', type='Question'), target=Node(id='Answer_38', type='Answer'), type='ANSWERED_BY')], source=Document(page_content='{"id": 38, "question": "Is cancellation allowed for falcon transportation?", "answer": "Yes, cancellation is allowed free of charge for falcon transportation. The residual value can be issued for further transportation or refund."}')),
#  GraphDocument(nodes=[Node(id='39', type='Question', properties={'text': 'Is transportation of falcons allowed on all flights?'}), Node(id='Answer_39', type='Answer', properties={'text': 'Yes, transportation of falcons is allowed on all flights except on flights to/from Tunis.'})], relationships=[Relationship(source=Node(id='39', type='Question'), target=Node(id='Answer_39', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 39, "question": "Is transportation of falcons allowed on all flights?", "answer": "Yes, transportation of falcons is allowed on all flights except on flights to/from Tunis."}')),
#  GraphDocument(nodes=[Node(id='23', type='Question', properties={'text': 'How much does it cost to transport a falcon from Africa to Australia, New Zealand, Japan, or South Korea?'}), Node(id='23_Answer', type='Answer', properties={'text': 'The cost for transporting a falcon from Africa to Australia, New Zealand, Japan, or South Korea is 630 USD.'}), Node(id='Falcon', type='Pet'), Node(id='Africa', type='Geo'), Node(id='Australia', type='Geo'), Node(id='New Zealand', type='Geo'), Node(id='Japan', type='Geo'), Node(id='South Korea', type='Geo'), Node(id='630 Usd', type='Fee')], relationships=[Relationship(source=Node(id='23', type='Question'), target=Node(id='23_Answer', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='23_Answer', type='Answer'), target=Node(id='Falcon', type='Pet'), type='MENTIONS'), Relationship(source=Node(id='23_Answer', type='Answer'), target=Node(id='Africa', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='23_Answer', type='Answer'), target=Node(id='Australia', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='23_Answer', type='Answer'), target=Node(id='New Zealand', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='23_Answer', type='Answer'), target=Node(id='Japan', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='23_Answer', type='Answer'), target=Node(id='South Korea', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='23_Answer', type='Answer'), target=Node(id='630 Usd', type='Fee'), type='MENTIONS')], source=Document(page_content='{"id": 23, "question": "How much does it cost to transport a falcon from Africa to Australia, New Zealand, Japan, or South Korea?", "answer": "The cost for transporting a falcon from Africa to Australia, New Zealand, Japan, or South Korea is 630 USD."}')),
#  GraphDocument(nodes=[Node(id='41', type='Question', properties={'text': 'Can I bring my falcon on flights to/from Tunis?'}), Node(id='Answer_41', type='Answer', properties={'text': 'No, the carriage of falcons within the passenger cabin is not permitted on flights to/from Tunis.'})], relationships=[Relationship(source=Node(id='41', type='Question'), target=Node(id='Answer_41', type='Answer'), type='ANSWERED_BY')], source=Document(page_content='{"id": 41, "question": "Can I bring my falcon on flights to/from Tunis?", "answer": "No, the carriage of falcons within the passenger cabin is not permitted on flights to/from Tunis."}')),
#  GraphDocument(nodes=[Node(id='29', type='Question', properties={'text': 'How much does it cost to transport a falcon from Europe to Australia, New Zealand, Japan, or South Korea?'}), Node(id='29_Answer', type='Answer', properties={'text': 'The cost for transporting a falcon from Europe to Australia, New Zealand, Japan, or South Korea is 630 USD.'}), Node(id='Falcon', type='Pet'), Node(id='Europe', type='Geo'), Node(id='Australia', type='Geo'), Node(id='New Zealand', type='Geo'), Node(id='Japan', type='Geo'), Node(id='South Korea', type='Geo'), Node(id='630 Usd', type='Fee')], relationships=[Relationship(source=Node(id='29', type='Question'), target=Node(id='29_Answer', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='29_Answer', type='Answer'), target=Node(id='Falcon', type='Pet'), type='MENTIONS'), Relationship(source=Node(id='29_Answer', type='Answer'), target=Node(id='Europe', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='29_Answer', type='Answer'), target=Node(id='Australia', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='29_Answer', type='Answer'), target=Node(id='New Zealand', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='29_Answer', type='Answer'), target=Node(id='Japan', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='29_Answer', type='Answer'), target=Node(id='South Korea', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='29_Answer', type='Answer'), target=Node(id='630 Usd', type='Fee'), type='MENTIONS')], source=Document(page_content='{"id": 29, "question": "How much does it cost to transport a falcon from Europe to Australia, New Zealand, Japan, or South Korea?", "answer": "The cost for transporting a falcon from Europe to Australia, New Zealand, Japan, or South Korea is 630 USD."}')),
#  GraphDocument(nodes=[Node(id='40', type='Question', properties={'text': 'Can I bring a falcon in the Economy Class cabin?'}), Node(id='Answer_40', type='Answer', properties={'text': 'Yes, you can transport a falcon in the Economy Class cabin. However, please note that specific baggage rates apply for this service.'})], relationships=[Relationship(source=Node(id='40', type='Question'), target=Node(id='Answer_40', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 40, "question": "Can I bring a falcon in the Economy Class cabin?", "answer": "Yes, you can transport a falcon in the Economy Class cabin. However, please note that specific baggage rates apply for this service."}')),
#  GraphDocument(nodes=[Node(id='43', type='Question', properties={'text': 'Are changes allowed for falcon transportation?'}), Node(id='Answer_43', type='Answer', properties={'text': 'Yes, changes are permitted free of charge for falcon transportation on Qatar Airways.'})], relationships=[Relationship(source=Node(id='43', type='Question'), target=Node(id='Answer_43', type='Answer'), type='ANSWERED_BY')], source=Document(page_content='{"id": 43, "question": "Are changes allowed for falcon transportation?", "answer": "Yes, changes are permitted free of charge for falcon transportation on Qatar Airways."}')),
#  GraphDocument(nodes=[Node(id='42', type='Question', properties={'text': 'Can I transport a falcon in the Economy Class cabin?'}), Node(id='Answer_42', type='Answer', properties={'text': 'Yes, you can transport a falcon in the Economy Class cabin. However, please note that specific baggage rates apply for this service.'})], relationships=[Relationship(source=Node(id='42', type='Question'), target=Node(id='Answer_42', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 42, "question": "Can I transport a falcon in the Economy Class cabin?", "answer": "Yes, you can transport a falcon in the Economy Class cabin. However, please note that specific baggage rates apply for this service."}')),
#  GraphDocument(nodes=[Node(id='44', type='Question', properties={'text': 'Can I carry a falcon in the passenger cabin on flights to/from Tunis?'}), Node(id='Answer_44', type='Answer', properties={'text': 'No, the carriage of falcons within the passenger cabin of a Qatar Airways aircraft is not permitted on flights to/from Tunis.'})], relationships=[Relationship(source=Node(id='44', type='Question'), target=Node(id='Answer_44', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 44, "question": "Can I carry a falcon in the passenger cabin on flights to/from Tunis?", "answer": "No, the carriage of falcons within the passenger cabin of a Qatar Airways aircraft is not permitted on flights to/from Tunis."}')),
#  GraphDocument(nodes=[Node(id='45', type='Question', properties={'text': 'Are baggage rates for falcon transportation subject to change?'}), Node(id='Answer_45', type='Answer', properties={'text': 'Yes, the baggage rates for transporting falcons are subject to change without prior notice.'})], relationships=[Relationship(source=Node(id='45', type='Question'), target=Node(id='Answer_45', type='Answer'), type='ANSWERED_BY')], source=Document(page_content='{"id": 45, "question": "Are baggage rates for falcon transportation subject to change?", "answer": "Yes, the baggage rates for transporting falcons are subject to change without prior notice."}')),
#  GraphDocument(nodes=[Node(id='46', type='Question', properties={'text': 'Are there any limitations to the number of changes allowed for falcon transportation?'}), Node(id='46_Answer', type='Answer', properties={'text': "There are no specific limitations mentioned regarding the number of changes allowed for falcon transportation. However, it's always recommended to check with Qatar Airways for any additional restrictions or limitations based on your specific itinerary."})], relationships=[Relationship(source=Node(id='46', type='Question'), target=Node(id='46_Answer', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 46, "question": "Are there any limitations to the number of changes allowed for falcon transportation?", "answer": "There are no specific limitations mentioned regarding the number of changes allowed for falcon transportation. However, it\'s always recommended to check with Qatar Airways for any additional restrictions or limitations based on your specific itinerary."}')),
#  GraphDocument(nodes=[Node(id='48', type='Question', properties={'text': "What happens if my pet's container is too small?"}), Node(id='Answer_48', type='Answer', properties={'text': "If Qatar Airways finds that your pet's container is too small, we reserve the right to refuse the transport of the animal. We prioritize the well-being of pets during travel."})], relationships=[Relationship(source=Node(id='48', type='Question'), target=Node(id='Answer_48', type='Answer'), type='ANSWERED_BY')], source=Document(page_content='{"id": 48, "question": "What happens if my pet\'s container is too small?", "answer": "If Qatar Airways finds that your pet\'s container is too small, we reserve the right to refuse the transport of the animal. We prioritize the well-being of pets during travel."}')),
#  GraphDocument(nodes=[Node(id='51', type='Question', properties={'text': 'Are pet falcons allowed in the cabin?'}), Node(id='51_Answer', type='Answer', properties={'text': 'Yes, you can carry one falcon in the Economy Class cabin of an aircraft. However, please note that a maximum of six falcons are permitted within the Economy Class cabin of any one aircraft. Please also check the country regulations for any additional restrictions.'})], relationships=[Relationship(source=Node(id='51', type='Question'), target=Node(id='51_Answer', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 51, "question": "Are pet falcons allowed in the cabin?", "answer": "Yes, you can carry one falcon in the Economy Class cabin of an aircraft. However, please note that a maximum of six falcons are permitted within the Economy Class cabin of any one aircraft. Please also check the country regulations for any additional restrictions."}')),
#  GraphDocument(nodes=[Node(id='47', type='Question', properties={'text': 'How many falcons can I carry in the Economy Class cabin?'}), Node(id='47_Answer', type='Answer', properties={'text': 'You can carry one falcon in the Economy Class cabin of an aircraft. However, please note that a maximum of six falcons are permitted within the Economy Class cabin of any one aircraft, subject to country regulations.'})], relationships=[Relationship(source=Node(id='47', type='Question'), target=Node(id='47_Answer', type='Answer'), type='ANSWERED_BY')], source=Document(page_content='{"id": 47, "question": "How many falcons can I carry in the Economy Class cabin?", "answer": "You can carry one falcon in the Economy Class cabin of an aircraft. However, please note that a maximum of six falcons are permitted within the Economy Class cabin of any one aircraft, subject to country regulations."}')),
#  GraphDocument(nodes=[Node(id='49', type='Question', properties={'text': 'Are falcons allowed in the Economy Class cabin?'}), Node(id='49_Answer', type='Answer', properties={'text': 'Yes, you can bring falcons in the Economy Class cabin. However, there is a limit of one falcon per passenger, and a maximum of six falcons are allowed within the Economy Class cabin on any one aircraft, subject to country regulations.'})], relationships=[Relationship(source=Node(id='49', type='Question'), target=Node(id='49_Answer', type='Answer'), type='ANSWER')], source=Document(page_content='{"id": 49, "question": "Are falcons allowed in the Economy Class cabin?", "answer": "Yes, you can bring falcons in the Economy Class cabin. However, there is a limit of one falcon per passenger, and a maximum of six falcons are allowed within the Economy Class cabin on any one aircraft, subject to country regulations."}')),
# ...
#  GraphDocument(nodes=[Node(id='337', type='Question', properties={'text': 'What is the fee for transporting a pet within Iran?'}), Node(id='Fee_Transporting_Pet_Within_Iran', type='Answer', properties={'text': 'The fee for transporting your pet within Iran is USD 45.'}), Node(id='Iran', type='Geo')], relationships=[Relationship(source=Node(id='337', type='Question'), target=Node(id='Fee_Transporting_Pet_Within_Iran', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Fee_Transporting_Pet_Within_Iran', type='Answer'), target=Node(id='Iran', type='Geo'), type='RELATED_TO')], source=Document(page_content='{"id": 337, "question": "What is the fee for transporting a pet within Iran?", "answer": "The fee for transporting your pet within Iran is USD 45."}')),
#  GraphDocument(nodes=[Node(id='344', type='Question', properties={'text': 'What is the fee to transport my pet from Qatar to the Levant?'}), Node(id='Fee_344', type='Fee', properties={'amount': 'USD 30'}), Node(id='Qatar', type='Geo'), Node(id='Levant', type='Geo'), Node(id='Pet_344', type='Pet')], relationships=[Relationship(source=Node(id='344', type='Question'), target=Node(id='Fee_344', type='Fee'), type='HAS_ANSWER'), Relationship(source=Node(id='Fee_344', type='Fee'), target=Node(id='Pet_344', type='Pet'), type='FOR'), Relationship(source=Node(id='Qatar', type='Geo'), target=Node(id='Levant', type='Geo'), type='TO')], source=Document(page_content='{"id": 344, "question": "What is the fee to transport my pet from Qatar to the Levant?", "answer": "The pet transportation fee from Qatar to the Levant is USD 30."}')),
#  GraphDocument(nodes=[Node(id='345', type='Question', properties={'text': 'How much will it cost to transport my pet from Central Asia to Iran?'}), Node(id='Pet_Transport_Fee', type='Answer', properties={'text': 'The pet transportation fee from Central Asia to Iran is USD 30.'}), Node(id='Central Asia', type='Geo'), Node(id='Iran', type='Geo'), Node(id='Pet', type='Pet')], relationships=[Relationship(source=Node(id='345', type='Question'), target=Node(id='Pet_Transport_Fee', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Pet_Transport_Fee', type='Answer'), target=Node(id='Central Asia', type='Geo'), type='FROM'), Relationship(source=Node(id='Pet_Transport_Fee', type='Answer'), target=Node(id='Iran', type='Geo'), type='TO'), Relationship(source=Node(id='Pet_Transport_Fee', type='Answer'), target=Node(id='Pet', type='Pet'), type='RELATED_TO'), Relationship(source=Node(id='Pet_Transport_Fee', type='Answer'), target=Node(id='Fee', type='Fee'), type='COST')], source=Document(page_content='{"id": 345, "question": "How much will it cost to transport my pet from Central Asia to Iran?", "answer": "The pet transportation fee from Central Asia to Iran is USD 30."}')),
#  GraphDocument(nodes=[Node(id='343', type='Question', properties={'text': 'I am traveling from the ISC & Pakistan region to Qatar. How much will I be charged for pet transportation?'}), Node(id='Pet_Transportation_Fee_Isc_Pakistan_Qatar', type='Answer', properties={'text': 'The pet transportation fee from ISC & Pakistan to Qatar is USD 10.'}), Node(id='Isc_Pakistan', type='Geo', properties={'name': 'ISC & Pakistan'}), Node(id='Qatar', type='Geo', properties={'name': 'Qatar'}), Node(id='Pet_Transportation_Fee', type='Fee', properties={'amount': 'USD 10'})], relationships=[Relationship(source=Node(id='343', type='Question'), target=Node(id='Pet_Transportation_Fee_Isc_Pakistan_Qatar', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Pet_Transportation_Fee_Isc_Pakistan_Qatar', type='Answer'), target=Node(id='Isc_Pakistan', type='Geo'), type='FROM'), Relationship(source=Node(id='Pet_Transportation_Fee_Isc_Pakistan_Qatar', type='Answer'), target=Node(id='Qatar', type='Geo'), type='TO'), Relationship(source=Node(id='Pet_Transportation_Fee_Isc_Pakistan_Qatar', type='Answer'), target=Node(id='Pet_Transportation_Fee', type='Fee'), type='MENTIONS')], source=Document(page_content='{"id": 343, "question": "I am traveling from the ISC & Pakistan region to Qatar. How much will I be charged for pet transportation?", "answer": "The pet transportation fee from ISC & Pakistan to Qatar is USD 10."}')),
#  GraphDocument(nodes=[Node(id='347', type='Question', properties={'text': 'What is the cost of transporting a pet from the Levant to the GCC?'}), Node(id='Pet_Transportation_Fee_Levant_Gcc', type='Answer', properties={'text': 'The pet transportation fee from the Levant to the GCC is USD 2100.'}), Node(id='Levant', type='Geo'), Node(id='Gcc', type='Geo'), Node(id='Pet', type='Pet'), Node(id='Fee', type='Fee', properties={'amount': 'USD 2100'})], relationships=[Relationship(source=Node(id='347', type='Question'), target=Node(id='Pet_Transportation_Fee_Levant_Gcc', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Pet_Transportation_Fee_Levant_Gcc', type='Answer'), target=Node(id='Levant', type='Geo'), type='FROM'), Relationship(source=Node(id='Pet_Transportation_Fee_Levant_Gcc', type='Answer'), target=Node(id='Gcc', type='Geo'), type='TO'), Relationship(source=Node(id='Pet_Transportation_Fee_Levant_Gcc', type='Answer'), target=Node(id='Pet', type='Pet'), type='RELATED_TO'), Relationship(source=Node(id='Pet_Transportation_Fee_Levant_Gcc', type='Answer'), target=Node(id='Fee', type='Fee'), type='HAS_FEE')], source=Document(page_content='{"id": 347, "question": "What is the cost of transporting a pet from the Levant to the GCC?", "answer": "The pet transportation fee from the Levant to the GCC is USD 2100."}')),
#  GraphDocument(nodes=[Node(id='346', type='Question', properties={'text': 'I am traveling from South/East Asia to Iran. What is the pet transportation fee?'}), Node(id='Pet_Transportation_Fee_346', type='Answer', properties={'text': 'The pet transportation fee from South/East Asia to Iran is USD 20.'}), Node(id='South/East Asia', type='Geo'), Node(id='Iran', type='Geo'), Node(id='Usd 20', type='Fee')], relationships=[Relationship(source=Node(id='346', type='Question'), target=Node(id='Pet_Transportation_Fee_346', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Pet_Transportation_Fee_346', type='Answer'), target=Node(id='South/East Asia', type='Geo'), type='FROM'), Relationship(source=Node(id='Pet_Transportation_Fee_346', type='Answer'), target=Node(id='Iran', type='Geo'), type='TO'), Relationship(source=Node(id='Pet_Transportation_Fee_346', type='Answer'), target=Node(id='Usd 20', type='Fee'), type='COST')], source=Document(page_content='{"id": 346, "question": "I am traveling from South/East Asia to Iran. What is the pet transportation fee?", "answer": "The pet transportation fee from South/East Asia to Iran is USD 20."}')),
#  GraphDocument(nodes=[Node(id='348', type='Question', properties={'text': 'How much does it cost to transport a pet from Australasia to the GCC?'}), Node(id='Fee_348', type='Answer', properties={'text': 'The fee for transporting a pet from Australasia to the GCC is USD 30.'}), Node(id='Australasia', type='Geo'), Node(id='Gcc', type='Geo'), Node(id='Pet_348', type='Pet')], relationships=[Relationship(source=Node(id='348', type='Question'), target=Node(id='Fee_348', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Fee_348', type='Answer'), target=Node(id='Australasia', type='Geo'), type='FROM'), Relationship(source=Node(id='Fee_348', type='Answer'), target=Node(id='Gcc', type='Geo'), type='TO'), Relationship(source=Node(id='Fee_348', type='Answer'), target=Node(id='Pet_348', type='Pet'), type='FOR')], source=Document(page_content='{"id": 348, "question": "How much does it cost to transport a pet from Australasia to the GCC?", "answer": "The fee for transporting a pet from Australasia to the GCC is USD 30."}')),
#  GraphDocument(nodes=[Node(id='349', type='Question', properties={'text': "I'm traveling from Qatar to Iran with my pet. What is the transportation fee?"}), Node(id='Answer_349', type='Answer', properties={'text': 'The fee for transporting a pet from Qatar to Iran is USD 40.'}), Node(id='Qatar', type='Geo'), Node(id='Iran', type='Geo'), Node(id='Pet_349', type='Pet'), Node(id='Fee_349', type='Fee', properties={'amount': 'USD 40'})], relationships=[Relationship(source=Node(id='349', type='Question'), target=Node(id='Answer_349', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='349', type='Question'), target=Node(id='Qatar', type='Geo'), type='FROM'), Relationship(source=Node(id='349', type='Question'), target=Node(id='Iran', type='Geo'), type='TO'), Relationship(source=Node(id='349', type='Question'), target=Node(id='Pet_349', type='Pet'), type='ABOUT'), Relationship(source=Node(id='Answer_349', type='Answer'), target=Node(id='Fee_349', type='Fee'), type='MENTIONS_FEE')], source=Document(page_content='{"id": 349, "question": "I\'m traveling from Qatar to Iran with my pet. What is the transportation fee?", "answer": "The fee for transporting a pet from Qatar to Iran is USD 40."}')),
#  GraphDocument(nodes=[Node(id='353', type='Question', properties={'text': 'Can I bring my pet on a Qatar Airways flight from the GCC to Australasia?'}), Node(id='Answer_353', type='Answer', properties={'text': 'This information is not available in the provided text. Please refer to the Qatar Airways website section about pets or contact customer support for detailed information about traveling with animals.'})], relationships=[Relationship(source=Node(id='353', type='Question'), target=Node(id='Answer_353', type='Answer'), type='HAS_ANSWER')], source=Document(page_content='{"id": 353, "question": "Can I bring my pet on a Qatar Airways flight from the GCC to Australasia?", "answer": "This information is not available in the provided text. Please refer to the Qatar Airways website section about pets or contact customer support for detailed information about traveling with animals."}')),
#  GraphDocument(nodes=[Node(id='354', type='Question', properties={'text': 'Can I bring my cat with me in the cabin on my Qatar Airways flight?'}), Node(id='Qatar Airways', type='Policy', properties={'text': "Qatar Airways' policy on animals in the cabin varies depending on your destination and the type of animal. Please contact their customer service to confirm if your cat is allowed in the cabin for your specific flight."}), Node(id='Cat', type='Pet')], relationships=[Relationship(source=Node(id='354', type='Question'), target=Node(id='Qatar Airways', type='Policy'), type='RELATED_TO'), Relationship(source=Node(id='354', type='Question'), target=Node(id='Cat', type='Pet'), type='MENTIONS')], source=Document(page_content='{"id": 354, "question": "Can I bring my cat with me in the cabin on my Qatar Airways flight?", "answer": "Qatar Airways\' policy on animals in the cabin varies depending on your destination and the type of animal. Please contact their customer service to confirm if your cat is allowed in the cabin for your specific flight."}')),
#  GraphDocument(nodes=[Node(id='351', type='Question', properties={'text': 'I need to transport my pet from Central Asia to Qatar. How much will it cost?'}), Node(id='Answer_351', type='Answer', properties={'text': 'The pet transportation fee from Central Asia to Qatar is USD 13.'}), Node(id='Pet_Transportation_Fee', type='Fee', properties={'amount': 'USD 13'}), Node(id='Central Asia', type='Geo'), Node(id='Qatar', type='Geo')], relationships=[Relationship(source=Node(id='351', type='Question'), target=Node(id='Answer_351', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Answer_351', type='Answer'), target=Node(id='Pet_Transportation_Fee', type='Fee'), type='MENTIONS'), Relationship(source=Node(id='Pet_Transportation_Fee', type='Fee'), target=Node(id='Central Asia', type='Geo'), type='FROM'), Relationship(source=Node(id='Pet_Transportation_Fee', type='Fee'), target=Node(id='Qatar', type='Geo'), type='TO')], source=Document(page_content='{"id": 351, "question": "I need to transport my pet from Central Asia to Qatar. How much will it cost?", "answer": "The pet transportation fee from Central Asia to Qatar is USD 13."}')),
#  GraphDocument(nodes=[Node(id='355', type='Question', properties={'text': 'Can I travel with my service dog on a Qatar Airways flight?'}), Node(id='Qatar Airways', type='Policy', properties={'guidelines': 'Qatar Airways has specific guidelines for traveling with service animals. Contact their customer service well in advance of your flight to ensure you meet all requirements and necessary documentation.'}), Node(id='Service Dog', type='Pet')], relationships=[Relationship(source=Node(id='355', type='Question'), target=Node(id='Qatar Airways', type='Policy'), type='RELATED_TO'), Relationship(source=Node(id='355', type='Question'), target=Node(id='Service Dog', type='Pet'), type='MENTIONS')], source=Document(page_content='{"id": 355, "question": "Can I travel with my service dog on a Qatar Airways flight?", "answer": "Qatar Airways has specific guidelines for traveling with service animals. Contact their customer service well in advance of your flight to ensure you meet all requirements and necessary documentation."}')),
#  GraphDocument(nodes=[Node(id='350', type='Question', properties={'text': 'What is the charge for pet transportation from Japan & Korea to Qatar?'}), Node(id='Answer_350', type='Answer', properties={'text': 'The pet transportation fee from Japan & Korea to Qatar is USD 13.'}), Node(id='Japan', type='Geo'), Node(id='Korea', type='Geo'), Node(id='Qatar', type='Geo'), Node(id='Pet_Transportation_Fee_Japan_Korea_Qatar', type='Fee', properties={'amount': 'USD 13'})], relationships=[Relationship(source=Node(id='350', type='Question'), target=Node(id='Answer_350', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Japan', type='Geo'), target=Node(id='Pet_Transportation_Fee_Japan_Korea_Qatar', type='Fee'), type='RELATED_TO'), Relationship(source=Node(id='Korea', type='Geo'), target=Node(id='Pet_Transportation_Fee_Japan_Korea_Qatar', type='Fee'), type='RELATED_TO'), Relationship(source=Node(id='Qatar', type='Geo'), target=Node(id='Pet_Transportation_Fee_Japan_Korea_Qatar', type='Fee'), type='RELATED_TO')], source=Document(page_content='{"id": 350, "question": "What is the charge for pet transportation from Japan & Korea to Qatar?", "answer": "The pet transportation fee from Japan & Korea to Qatar is USD 13."}')),
#  GraphDocument(nodes=[Node(id='352', type='Question'), Node(id='Fee_352', type='Fee', properties={'amount': 'USD 10'}), Node(id='Pet_Transportation', type='Pet'), Node(id='Levant', type='Geo'), Node(id='Iran', type='Geo'), Node(id='Answer_352', type='Answer')], relationships=[Relationship(source=Node(id='352', type='Question'), target=Node(id='Fee_352', type='Fee'), type='RELATED_TO'), Relationship(source=Node(id='352', type='Question'), target=Node(id='Pet_Transportation', type='Pet'), type='RELATED_TO'), Relationship(source=Node(id='352', type='Question'), target=Node(id='Levant', type='Geo'), type='RELATED_TO'), Relationship(source=Node(id='352', type='Question'), target=Node(id='Iran', type='Geo'), type='RELATED_TO'), Relationship(source=Node(id='352', type='Question'), target=Node(id='Answer_352', type='Answer'), type='HAS_ANSWER'), Relationship(source=Node(id='Answer_352', type='Answer'), target=Node(id='Fee_352', type='Fee'), type='MENTIONS'), Relationship(source=Node(id='Answer_352', type='Answer'), target=Node(id='Pet_Transportation', type='Pet'), type='MENTIONS'), Relationship(source=Node(id='Answer_352', type='Answer'), target=Node(id='Levant', type='Geo'), type='MENTIONS'), Relationship(source=Node(id='Answer_352', type='Answer'), target=Node(id='Iran', type='Geo'), type='MENTIONS')], source=Document(page_content='{"id": 352, "question": "What is the fee for transporting a pet from the Levant to Iran?", "answer": "The pet transportation fee from the Levant to Iran is USD 10."}'))]
